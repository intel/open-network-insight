# %%
# !hive -e "describe vast_netflow;"
# Out:
# 15/06/08 15:07:52 WARN conf.HiveConf: DEPRECATED: Configuration property hive.metastore.local no longer has any effect. Make sure to provide a valid value for hive.metastore.uris if you are connecting to a remote metastore.
#
# Logging initialized using configuration in jar:file:/opt/cloudera/parcels/CDH-5.3.1-1.cdh5.3.1.p0.5/jars/hive-common-0.13.1-cdh5.3.1.jar!/hive-log4j.properties
# OK
# timeseconds         	float
# parseddate          	timestamp
# datetimestr         	string
# iplayerprotocol     	int
# iplayerprotocolcode 	string
# firstseensrcip      	string
# firstseendestip     	string
# firstseensrcport    	int
# firstseendestport   	int
# morefragments       	string
# contfragments       	string
# durationseconds     	int
# firstseensrcpayloadbytes	int
# firstseendestpayloadbytes	int
# firstseensrctotalbytes	int
# firstseendesttotalbytes	int
# firstseensrcpacketcount	int
# firstseendestpacketcount	int
# recordforceout      	string
# Time taken: 0.798 seconds, Fetched: 19 row(s)

# %%
day = 6

# %%
# !hive -S -e "set hive.cli.print.header=true; select firstseensrcip as sip,firstseendestip as dip \
from vast_netflow WHERE day(parseddate) = 6 and hour(parseddate)=14 \
GROUP BY firstseensrcip, firstseendestip " > /home/hadoop/ipython/user/jasantos/vastday6_hr14_mat.tsv
# Out:
# 15/06/04 15:44:14 WARN conf.HiveConf: DEPRECATED: Configuration property hive.metastore.local no longer has any effect. Make sure to provide a valid value for hive.metastore.uris if you are connecting to a remote metastore.

# %%
# !hive -S -e "set hive.cli.print.header=true; select firstseensrcip as sip,firstseendestip as dip \
from vast_netflow WHERE day(parseddate) = 10 \
GROUP BY firstseensrcip, firstseendestip " > /home/hadoop/ipython/user/jasantos/vastday10_mat
# Out:
# 15/06/05 11:27:35 WARN conf.HiveConf: DEPRECATED: Configuration property hive.metastore.local no longer has any effect. Make sure to provide a valid value for hive.metastore.uris if you are connecting to a remote metastore.

# %%
# !hive -S -e "set hive.cli.print.header=true; select firstseensrcip as srcIP,firstseendestip as dstIP,iplayerprotocol,firstseensrcport, \
firstseendestport,min(firstseensrctotalbytes) as minsrcbytes,max(firstseensrctotalbytes) as maxsrcbytes, \
avg(firstseensrctotalbytes) as avgsrcbytes, \
min(firstseendesttotalbytes) as mindestbytes, max(firstseendesttotalbytes) as maxdestbytes, \
avg(firstseendesttotalbytes) as avgdestbytes, count(firstseensrcip) as conns, dateTimeStr \
from vast_netflow WHERE day(parseddate) = 10 \
GROUP BY firstseensrcip, firstseendestip, firstseensrcport,firstseendestport,iplayerprotocol,dateTimeStr " > /home/hadoop/ipython/user/jasantos/vastday10_time.tsv
# Out:
# 15/06/08 15:08:25 WARN conf.HiveConf: DEPRECATED: Configuration property hive.metastore.local no longer has any effect. Make sure to provide a valid value for hive.metastore.uris if you are connecting to a remote metastore.

# %%
# File for src port and dest port histograms
# !hive -S -e "set hive.cli.print.header=true; select firstseensrcip as srcIP,firstseendestip as dstIP,firstseensrcport, \
firstseendestport, count(firstseensrcip) as conns \
from vast_netflow WHERE day(parseddate) = 6 \
GROUP BY firstseensrcip, firstseendestip, firstseensrcport,firstseendestport " > /home/hadoop/ipython/user/jasantos/vastday6_ports.tsv
# Out:
# 15/06/26 14:56:57 WARN conf.HiveConf: DEPRECATED: Configuration property hive.metastore.local no longer has any effect. Make sure to provide a valid value for hive.metastore.uris if you are connecting to a remote metastore.

# %%
# !hive -e "describe netflow_poc;"
# Out:
# 15/07/07 09:52:16 WARN conf.HiveConf: DEPRECATED: Configuration property hive.metastore.local no longer has any effect. Make sure to provide a valid value for hive.metastore.uris if you are connecting to a remote metastore.
#
# Logging initialized using configuration in jar:file:/opt/cloudera/parcels/CDH-5.3.1-1.cdh5.3.1.p0.5/jars/hive-common-0.13.1-cdh5.3.1.jar!/hive-log4j.properties
# OK
# tstart              	timestamp
# tend                	timestamp
# tdur                	float
# sip                 	string
# dip                 	string
# sport               	int
# dport               	int
# proto               	string
# flag                	string
# fwd                 	int
# stos                	int
# ipkt                	int
# ibyt                	int
# opkt                	int
# obyt                	int
# input               	int
# output              	int
# year                	int
# month               	int
# day                 	int
# hour                	int
#
# # Partition Information
# # col_name            	data_type           	comment
#
# year                	int
# month               	int
# day                 	int
# hour                	int
# Time taken: 0.752 seconds, Fetched: 29 row(s)
# 15/07/07 09:52:22 WARN conf.HiveConf: DEPRECATED: Configuration property hive.metastore.local no longer has any effect. Make sure to provide a valid value for hive.metastore.uris if you are connecting to a remote metastore.
#
# Logging initialized using configuration in jar:file:/opt/cloudera/parcels/CDH-5.3.1-1.cdh5.3.1.p0.5/jars/hive-common-0.13.1-cdh5.3.1.jar!/hive-log4j.properties
# FAILED: SemanticException [Error 10094]: Line 1:36 Dynamic partition cannot be the parent of a static partition 'day'

# %%
# !hive -e "show partitions netflow_poc;"
# Out:
# 15/07/07 09:53:21 WARN conf.HiveConf: DEPRECATED: Configuration property hive.metastore.local no longer has any effect. Make sure to provide a valid value for hive.metastore.uris if you are connecting to a remote metastore.
#
# Logging initialized using configuration in jar:file:/opt/cloudera/parcels/CDH-5.3.1-1.cdh5.3.1.p0.5/jars/hive-common-0.13.1-cdh5.3.1.jar!/hive-log4j.properties
# OK
# year=2015/month=4/day=17/hour=0
# year=2015/month=4/day=17/hour=1
# year=2015/month=4/day=17/hour=10
# year=2015/month=4/day=17/hour=11
# year=2015/month=4/day=17/hour=12
# year=2015/month=4/day=17/hour=13
# year=2015/month=4/day=17/hour=14
# year=2015/month=4/day=17/hour=15
# year=2015/month=4/day=17/hour=16
# year=2015/month=4/day=17/hour=17
# year=2015/month=4/day=17/hour=18
# year=2015/month=4/day=17/hour=19
# year=2015/month=4/day=17/hour=2
# year=2015/month=4/day=17/hour=20
# year=2015/month=4/day=17/hour=21
# year=2015/month=4/day=17/hour=22
# year=2015/month=4/day=17/hour=23
# year=2015/month=4/day=17/hour=3
# year=2015/month=4/day=17/hour=4
# year=2015/month=4/day=17/hour=5
# 15/08/06 10:23:48 WARN conf.HiveConf: DEPRECATED: Configuration property hive.metastore.local no longer has any effect. Make sure to provide a valid value for hive.metastore.uris if you are connecting to a remote metastore.
#
# Logging initialized using configuration in jar:file:/opt/cloudera/parcels/CDH-5.3.1-1.cdh5.3.1.p0.5/jars/hive-common-0.13.1-cdh5.3.1.jar!/hive-log4j.properties
# FAILED: SemanticException [Error 10001]: Line 1:42 Table not found 'netflow'

# %%
# !hive -e "set hive.cli.print.header=true; select sip, dip, sport, dport, flag \
from netflow_poc WHERE (sport=53 or dport=53) and flag!=\"......\"\
GROUP BY sip, dip, sport, dport, flag " > /home/hadoop/ipython/user/jasantos/test_flag_query3.tsv
# Out:
# 15/07/07 13:39:42 WARN conf.HiveConf: DEPRECATED: Configuration property hive.metastore.local no longer has any effect. Make sure to provide a valid value for hive.metastore.uris if you are connecting to a remote metastore.
#
# Logging initialized using configuration in jar:file:/opt/cloudera/parcels/CDH-5.3.1-1.cdh5.3.1.p0.5/jars/hive-common-0.13.1-cdh5.3.1.jar!/hive-log4j.properties
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks not specified. Estimated from input data size: 999
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1427480807408_18843, Tracking URL = http://master.css-gao-poc4.cluster.gao:8088/proxy/application_1427480807408_18843/
# Kill Command = /opt/cloudera/parcels/CDH-5.3.1-1.cdh5.3.1.p0.5/lib/hadoop/bin/hadoop job  -kill job_1427480807408_18843
# Hadoop job information for Stage-1: number of mappers: 5378; number of reducers: 999
# 2015-07-07 13:41:06,391 Stage-1 map = 0%,  reduce = 0%
# 2015-07-07 13:41:31,791 Stage-1 map = 1%,  reduce = 0%, Cumulative CPU 754.6 sec
# 2015-07-07 13:41:52,732 Stage-1 map = 2%,  reduce = 0%, Cumulative CPU 1148.63 sec
# 2015-07-07 13:42:14,742 Stage-1 map = 3%,  reduce = 0%, Cumulative CPU 1775.92 sec
# 2015-07-07 13:42:37,789 Stage-1 map = 4%,  reduce = 0%, Cumulative CPU 2245.13 sec
# 2015-07-07 13:42:58,718 Stage-1 map = 5%,  reduce = 0%, Cumulative CPU 2794.21 sec
# 2015-07-07 13:43:20,670 Stage-1 map = 6%,  reduce = 0%, Cumulative CPU 3258.39 sec
# 2015-07-07 13:43:40,504 Stage-1 map = 7%,  reduce = 0%, Cumulative CPU 3782.21 sec
# 2015-07-07 13:43:58,314 Stage-1 map = 8%,  reduce = 0%, Cumulative CPU 4245.35 sec
# 2015-07-07 13:44:16,074 Stage-1 map = 9%,  reduce = 0%, Cumulative CPU 4768.51 sec
# 2015-07-07 13:44:34,889 Stage-1 map = 10%,  reduce = 0%, Cumulative CPU 5231.79 sec
# 2015-07-07 13:44:56,815 Stage-1 map = 11%,  reduce = 0%, Cumulative CPU 5758.89 sec
# 2015-07-07 13:45:15,636 Stage-1 map = 12%,  reduce = 0%, Cumulative CPU 6274.84 sec
# 2015-07-07 13:45:35,484 Stage-1 map = 13%,  reduce = 0%, Cumulative CPU 6736.23 sec
# 2015-07-07 13:45:54,286 Stage-1 map = 14%,  reduce = 0%, Cumulative CPU 7239.64 sec
# 2015-07-07 13:46:14,119 Stage-1 map = 15%,  reduce = 0%, Cumulative CPU 7795.45 sec
# 2015-07-07 13:46:32,930 Stage-1 map = 16%,  reduce = 0%, Cumulative CPU 8211.65 sec
# 2015-07-07 13:46:49,630 Stage-1 map = 17%,  reduce = 0%, Cumulative CPU 8667.57 sec
# 2015-07-07 13:47:10,522 Stage-1 map = 18%,  reduce = 0%, Cumulative CPU 9226.26 sec
# 2015-07-07 13:47:29,323 Stage-1 map = 19%,  reduce = 0%, Cumulative CPU 9684.64 sec
# 2015-07-07 13:47:47,016 Stage-1 map = 20%,  reduce = 0%, Cumulative CPU 10122.05 sec
# 2015-07-07 13:48:05,838 Stage-1 map = 21%,  reduce = 0%, Cumulative CPU 10580.4 sec
# 2015-07-07 13:48:26,719 Stage-1 map = 22%,  reduce = 0%, Cumulative CPU 11106.44 sec
# 2015-07-07 13:48:41,358 Stage-1 map = 23%,  reduce = 0%, Cumulative CPU 11530.54 sec
# 2015-07-07 13:49:00,165 Stage-1 map = 24%,  reduce = 0%, Cumulative CPU 12025.31 sec
# 2015-07-07 13:49:18,959 Stage-1 map = 25%,  reduce = 0%, Cumulative CPU 12497.43 sec
# 2015-07-07 13:49:40,893 Stage-1 map = 26%,  reduce = 0%, Cumulative CPU 12992.23 sec
# 2015-07-07 13:49:56,560 Stage-1 map = 27%,  reduce = 0%, Cumulative CPU 13392.86 sec
# 2015-07-07 13:50:15,419 Stage-1 map = 28%,  reduce = 0%, Cumulative CPU 13881.68 sec
# 2015-07-07 13:50:33,206 Stage-1 map = 29%,  reduce = 0%, Cumulative CPU 14291.14 sec
# 2015-07-07 13:50:53,022 Stage-1 map = 30%,  reduce = 0%, Cumulative CPU 14761.11 sec
# 2015-07-07 13:51:09,714 Stage-1 map = 31%,  reduce = 0%, Cumulative CPU 15194.34 sec
# 2015-07-07 13:51:29,542 Stage-1 map = 32%,  reduce = 0%, Cumulative CPU 15751.32 sec
# 2015-07-07 13:51:46,263 Stage-1 map = 33%,  reduce = 0%, Cumulative CPU 16151.64 sec
# 2015-07-07 13:52:06,130 Stage-1 map = 34%,  reduce = 0%, Cumulative CPU 16612.83 sec
# 2015-07-07 13:52:22,902 Stage-1 map = 35%,  reduce = 0%, Cumulative CPU 17067.41 sec
# 2015-07-07 13:52:38,560 Stage-1 map = 36%,  reduce = 0%, Cumulative CPU 17452.36 sec
# 2015-07-07 13:52:53,159 Stage-1 map = 37%,  reduce = 0%, Cumulative CPU 17858.91 sec
# 2015-07-07 13:53:08,835 Stage-1 map = 38%,  reduce = 0%, Cumulative CPU 18359.42 sec
# 2015-07-07 13:53:22,402 Stage-1 map = 39%,  reduce = 0%, Cumulative CPU 18750.38 sec
# 2015-07-07 13:53:34,975 Stage-1 map = 40%,  reduce = 0%, Cumulative CPU 19190.36 sec
# 2015-07-07 13:53:50,726 Stage-1 map = 41%,  reduce = 0%, Cumulative CPU 19662.53 sec
# 2015-07-07 13:54:09,646 Stage-1 map = 42%,  reduce = 0%, Cumulative CPU 20130.68 sec
# 2015-07-07 13:54:21,197 Stage-1 map = 43%,  reduce = 0%, Cumulative CPU 20473.94 sec
# 2015-07-07 13:54:34,806 Stage-1 map = 44%,  reduce = 0%, Cumulative CPU 20880.68 sec
# 2015-07-07 13:54:48,489 Stage-1 map = 45%,  reduce = 0%, Cumulative CPU 21327.35 sec
# 2015-07-07 13:55:03,198 Stage-1 map = 46%,  reduce = 0%, Cumulative CPU 21769.64 sec
# 2015-07-07 13:55:17,892 Stage-1 map = 47%,  reduce = 0%, Cumulative CPU 22230.44 sec
# 2015-07-07 13:55:32,626 Stage-1 map = 48%,  reduce = 0%, Cumulative CPU 22671.15 sec
# 2015-07-07 13:55:43,121 Stage-1 map = 49%,  reduce = 0%, Cumulative CPU 22975.98 sec
# 2015-07-07 13:55:56,702 Stage-1 map = 50%,  reduce = 0%, Cumulative CPU 23431.84 sec
# 2015-07-07 13:56:13,430 Stage-1 map = 51%,  reduce = 0%, Cumulative CPU 23859.7 sec
# 2015-07-07 13:56:30,175 Stage-1 map = 52%,  reduce = 0%, Cumulative CPU 24304.49 sec
# 2015-07-07 13:56:43,808 Stage-1 map = 53%,  reduce = 0%, Cumulative CPU 24713.14 sec
# 2015-07-07 13:56:56,394 Stage-1 map = 54%,  reduce = 0%, Cumulative CPU 25084.3 sec
# 2015-07-07 13:57:14,219 Stage-1 map = 55%,  reduce = 0%, Cumulative CPU 25559.1 sec
# 2015-07-07 13:57:28,899 Stage-1 map = 56%,  reduce = 0%, Cumulative CPU 25991.42 sec
# 2015-07-07 13:57:43,621 Stage-1 map = 57%,  reduce = 0%, Cumulative CPU 26368.37 sec
# 2015-07-07 13:57:58,333 Stage-1 map = 58%,  reduce = 0%, Cumulative CPU 26828.98 sec
# 2015-07-07 13:58:10,936 Stage-1 map = 59%,  reduce = 0%, Cumulative CPU 27181.06 sec
# 2015-07-07 13:58:26,664 Stage-1 map = 60%,  reduce = 0%, Cumulative CPU 27716.68 sec
# 2015-07-07 13:58:42,408 Stage-1 map = 61%,  reduce = 0%, Cumulative CPU 28093.56 sec
# 2015-07-07 13:58:56,033 Stage-1 map = 62%,  reduce = 0%, Cumulative CPU 28483.3 sec
# 2015-07-07 13:59:11,849 Stage-1 map = 63%,  reduce = 0%, Cumulative CPU 28946.8 sec
# 2015-07-07 13:59:25,538 Stage-1 map = 64%,  reduce = 0%, Cumulative CPU 29301.79 sec
# 2015-07-07 13:59:42,426 Stage-1 map = 65%,  reduce = 0%, Cumulative CPU 29815.84 sec
# 2015-07-07 13:59:53,971 Stage-1 map = 66%,  reduce = 0%, Cumulative CPU 30200.46 sec
# 2015-07-07 14:00:07,591 Stage-1 map = 67%,  reduce = 0%, Cumulative CPU 30650.62 sec
# 2015-07-07 14:00:22,256 Stage-1 map = 68%,  reduce = 0%, Cumulative CPU 31059.03 sec
# 2015-07-07 14:00:36,884 Stage-1 map = 69%,  reduce = 0%, Cumulative CPU 31481.63 sec
# 2015-07-07 14:00:49,464 Stage-1 map = 70%,  reduce = 0%, Cumulative CPU 31910.27 sec
# 2015-07-07 14:01:04,214 Stage-1 map = 71%,  reduce = 0%, Cumulative CPU 32334.82 sec
# 2015-07-07 14:01:19,935 Stage-1 map = 72%,  reduce = 0%, Cumulative CPU 32797.97 sec
# 2015-07-07 14:01:36,719 Stage-1 map = 73%,  reduce = 0%, Cumulative CPU 33158.99 sec
# 2015-07-07 14:01:51,385 Stage-1 map = 74%,  reduce = 0%, Cumulative CPU 33600.81 sec
# 2015-07-07 14:02:06,086 Stage-1 map = 75%,  reduce = 0%, Cumulative CPU 34044.89 sec
# 2015-07-07 14:02:23,945 Stage-1 map = 76%,  reduce = 0%, Cumulative CPU 34472.0 sec
# 2015-07-07 14:02:38,651 Stage-1 map = 77%,  reduce = 0%, Cumulative CPU 34836.82 sec
# 2015-07-07 14:02:54,427 Stage-1 map = 78%,  reduce = 0%, Cumulative CPU 35274.87 sec
# 2015-07-07 14:03:07,060 Stage-1 map = 79%,  reduce = 0%, Cumulative CPU 35663.91 sec
# 2015-07-07 14:03:25,975 Stage-1 map = 80%,  reduce = 0%, Cumulative CPU 36209.49 sec
# 2015-07-07 14:03:42,764 Stage-1 map = 81%,  reduce = 0%, Cumulative CPU 36614.8 sec
# 2015-07-07 14:03:59,609 Stage-1 map = 82%,  reduce = 0%, Cumulative CPU 37029.19 sec
# 2015-07-07 14:04:10,137 Stage-1 map = 82%,  reduce = 1%, Cumulative CPU 37242.43 sec
# 2015-07-07 14:04:21,694 Stage-1 map = 83%,  reduce = 1%, Cumulative CPU 37570.15 sec
# 2015-07-07 14:04:44,818 Stage-1 map = 84%,  reduce = 1%, Cumulative CPU 38023.56 sec
# 2015-07-07 14:04:53,234 Stage-1 map = 84%,  reduce = 2%, Cumulative CPU 38146.88 sec
# 2015-07-07 14:05:10,015 Stage-1 map = 85%,  reduce = 2%, Cumulative CPU 38485.74 sec
# 2015-07-07 14:05:37,274 Stage-1 map = 86%,  reduce = 2%, Cumulative CPU 38945.5 sec
# 2015-07-07 14:06:02,453 Stage-1 map = 87%,  reduce = 2%, Cumulative CPU 39348.68 sec
# 2015-07-07 14:06:31,848 Stage-1 map = 88%,  reduce = 2%, Cumulative CPU 39795.49 sec
# 2015-07-07 14:06:59,202 Stage-1 map = 89%,  reduce = 2%, Cumulative CPU 40211.41 sec
# 2015-07-07 14:07:39,088 Stage-1 map = 90%,  reduce = 2%, Cumulative CPU 40673.96 sec
# 2015-07-07 14:08:22,237 Stage-1 map = 91%,  reduce = 2%, Cumulative CPU 41112.94 sec
# 2015-07-07 14:09:09,739 Stage-1 map = 92%,  reduce = 2%, Cumulative CPU 41575.39 sec
# 2015-07-07 14:10:09,942 Stage-1 map = 92%,  reduce = 2%, Cumulative CPU 42037.74 sec
# 2015-07-07 14:10:15,176 Stage-1 map = 93%,  reduce = 2%, Cumulative CPU 42074.23 sec
# 2015-07-07 14:11:08,632 Stage-1 map = 94%,  reduce = 2%, Cumulative CPU 42528.69 sec
# 2015-07-07 14:12:03,197 Stage-1 map = 95%,  reduce = 2%, Cumulative CPU 42976.37 sec
# 2015-07-07 14:12:54,645 Stage-1 map = 96%,  reduce = 2%, Cumulative CPU 43425.47 sec
# 2015-07-07 14:13:30,338 Stage-1 map = 97%,  reduce = 2%, Cumulative CPU 43856.48 sec
# 2015-07-07 14:14:13,287 Stage-1 map = 98%,  reduce = 2%, Cumulative CPU 44306.1 sec
# 2015-07-07 14:15:00,486 Stage-1 map = 99%,  reduce = 2%, Cumulative CPU 44755.29 sec
# 2015-07-07 14:16:01,396 Stage-1 map = 99%,  reduce = 2%, Cumulative CPU 45268.28 sec
# 2015-07-07 14:17:02,231 Stage-1 map = 99%,  reduce = 2%, Cumulative CPU 45427.4 sec
# 2015-07-07 14:17:03,277 Stage-1 map = 99%,  reduce = 3%, Cumulative CPU 45434.77 sec
# 2015-07-07 14:18:03,289 Stage-1 map = 99%,  reduce = 3%, Cumulative CPU 45714.24 sec
# 2015-07-07 14:19:04,244 Stage-1 map = 99%,  reduce = 3%, Cumulative CPU 45911.65 sec
# 2015-07-07 14:19:06,364 Stage-1 map = 100%,  reduce = 4%, Cumulative CPU 45922.82 sec
# 2015-07-07 14:19:07,439 Stage-1 map = 100%,  reduce = 7%, Cumulative CPU 46042.32 sec
# 2015-07-07 14:19:08,514 Stage-1 map = 100%,  reduce = 11%, Cumulative CPU 46219.18 sec
# 2015-07-07 14:19:19,197 Stage-1 map = 100%,  reduce = 12%, Cumulative CPU 46527.98 sec
# 2015-07-07 14:19:26,611 Stage-1 map = 100%,  reduce = 13%, Cumulative CPU 46699.82 sec
# 2015-07-07 14:19:38,219 Stage-1 map = 100%,  reduce = 14%, Cumulative CPU 46898.24 sec
# 2015-07-07 14:19:49,804 Stage-1 map = 100%,  reduce = 15%, Cumulative CPU 47037.88 sec
# 2015-07-07 14:19:52,970 Stage-1 map = 100%,  reduce = 16%, Cumulative CPU 47094.54 sec
# 2015-07-07 14:19:54,036 Stage-1 map = 100%,  reduce = 17%, Cumulative CPU 47155.03 sec
# 2015-07-07 14:19:55,104 Stage-1 map = 100%,  reduce = 20%, Cumulative CPU 47240.37 sec
# 2015-07-07 14:19:56,167 Stage-1 map = 100%,  reduce = 21%, Cumulative CPU 47316.61 sec
# 2015-07-07 14:19:57,235 Stage-1 map = 100%,  reduce = 22%, Cumulative CPU 47351.47 sec
# 2015-07-07 14:20:02,577 Stage-1 map = 100%,  reduce = 23%, Cumulative CPU 47440.09 sec
# 2015-07-07 14:20:06,806 Stage-1 map = 100%,  reduce = 24%, Cumulative CPU 47713.02 sec
# 2015-07-07 14:20:14,210 Stage-1 map = 100%,  reduce = 25%, Cumulative CPU 47885.41 sec
# 2015-07-07 14:20:26,920 Stage-1 map = 100%,  reduce = 26%, Cumulative CPU 48083.81 sec
# 2015-07-07 14:20:34,348 Stage-1 map = 100%,  reduce = 27%, Cumulative CPU 48180.82 sec
# 2015-07-07 14:20:36,457 Stage-1 map = 100%,  reduce = 28%, Cumulative CPU 48228.27 sec
# 2015-07-07 14:20:37,521 Stage-1 map = 100%,  reduce = 29%, Cumulative CPU 48276.18 sec
# 2015-07-07 14:20:38,588 Stage-1 map = 100%,  reduce = 30%, Cumulative CPU 48314.73 sec
# 2015-07-07 14:20:39,655 Stage-1 map = 100%,  reduce = 32%, Cumulative CPU 48380.15 sec
# 2015-07-07 14:20:40,715 Stage-1 map = 100%,  reduce = 33%, Cumulative CPU 48428.49 sec
# 2015-07-07 14:20:44,963 Stage-1 map = 100%,  reduce = 34%, Cumulative CPU 48510.57 sec
# 2015-07-07 14:20:49,205 Stage-1 map = 100%,  reduce = 35%, Cumulative CPU 48722.6 sec
# 2015-07-07 14:20:55,550 Stage-1 map = 100%,  reduce = 36%, Cumulative CPU 48904.05 sec
# 2015-07-07 14:21:05,046 Stage-1 map = 100%,  reduce = 37%, Cumulative CPU 49074.68 sec
# 2015-07-07 14:21:12,455 Stage-1 map = 100%,  reduce = 38%, Cumulative CPU 49188.21 sec
# 2015-07-07 14:21:14,550 Stage-1 map = 100%,  reduce = 39%, Cumulative CPU 49234.47 sec
# 2015-07-07 14:21:17,734 Stage-1 map = 100%,  reduce = 40%, Cumulative CPU 49314.89 sec
# 2015-07-07 14:21:18,791 Stage-1 map = 100%,  reduce = 41%, Cumulative CPU 49359.87 sec
# 2015-07-07 14:21:19,843 Stage-1 map = 100%,  reduce = 42%, Cumulative CPU 49400.3 sec
# 2015-07-07 14:21:20,914 Stage-1 map = 100%,  reduce = 43%, Cumulative CPU 49424.06 sec
# 2015-07-07 14:21:23,045 Stage-1 map = 100%,  reduce = 44%, Cumulative CPU 49482.14 sec
# 2015-07-07 14:21:25,177 Stage-1 map = 100%,  reduce = 45%, Cumulative CPU 49540.98 sec
# 2015-07-07 14:21:29,399 Stage-1 map = 100%,  reduce = 46%, Cumulative CPU 49719.76 sec
# 2015-07-07 14:21:35,729 Stage-1 map = 100%,  reduce = 47%, Cumulative CPU 49913.15 sec
# 2015-07-07 14:21:46,324 Stage-1 map = 100%,  reduce = 48%, Cumulative CPU 50071.81 sec
# 2015-07-07 14:21:53,739 Stage-1 map = 100%,  reduce = 49%, Cumulative CPU 50170.48 sec
# 2015-07-07 14:21:56,906 Stage-1 map = 100%,  reduce = 50%, Cumulative CPU 50226.98 sec
# 2015-07-07 14:21:59,030 Stage-1 map = 100%,  reduce = 51%, Cumulative CPU 50278.99 sec
# 2015-07-07 14:22:00,093 Stage-1 map = 100%,  reduce = 52%, Cumulative CPU 50314.38 sec
# 2015-07-07 14:22:02,216 Stage-1 map = 100%,  reduce = 53%, Cumulative CPU 50381.25 sec
# 2015-07-07 14:22:03,266 Stage-1 map = 100%,  reduce = 54%, Cumulative CPU 50410.63 sec
# 2015-07-07 14:22:06,424 Stage-1 map = 100%,  reduce = 55%, Cumulative CPU 50499.83 sec
# 2015-07-07 14:22:09,580 Stage-1 map = 100%,  reduce = 56%, Cumulative CPU 50612.68 sec
# 2015-07-07 14:22:13,804 Stage-1 map = 100%,  reduce = 57%, Cumulative CPU 50779.85 sec
# 2015-07-07 14:22:21,197 Stage-1 map = 100%,  reduce = 58%, Cumulative CPU 50932.13 sec
# 2015-07-07 14:22:28,593 Stage-1 map = 100%,  reduce = 59%, Cumulative CPU 51043.34 sec
# 2015-07-07 14:22:33,857 Stage-1 map = 100%,  reduce = 60%, Cumulative CPU 51131.62 sec
# 2015-07-07 14:22:35,982 Stage-1 map = 100%,  reduce = 61%, Cumulative CPU 51172.7 sec
# 2015-07-07 14:22:38,110 Stage-1 map = 100%,  reduce = 62%, Cumulative CPU 51223.44 sec
# 2015-07-07 14:22:40,253 Stage-1 map = 100%,  reduce = 63%, Cumulative CPU 51267.04 sec
# 2015-07-07 14:22:43,420 Stage-1 map = 100%,  reduce = 64%, Cumulative CPU 51369.72 sec
# 2015-07-07 14:22:45,539 Stage-1 map = 100%,  reduce = 65%, Cumulative CPU 51453.34 sec
# 2015-07-07 14:22:47,663 Stage-1 map = 100%,  reduce = 66%, Cumulative CPU 51521.92 sec
# 2015-07-07 14:22:50,833 Stage-1 map = 100%,  reduce = 67%, Cumulative CPU 51618.27 sec
# 2015-07-07 14:22:55,051 Stage-1 map = 100%,  reduce = 68%, Cumulative CPU 51752.03 sec
# 2015-07-07 14:22:59,271 Stage-1 map = 100%,  reduce = 69%, Cumulative CPU 51844.43 sec
# 2015-07-07 14:23:05,624 Stage-1 map = 100%,  reduce = 70%, Cumulative CPU 51960.91 sec
# 2015-07-07 14:23:11,977 Stage-1 map = 100%,  reduce = 71%, Cumulative CPU 52066.71 sec
# 2015-07-07 14:23:14,102 Stage-1 map = 100%,  reduce = 72%, Cumulative CPU 52118.77 sec
# 2015-07-07 14:23:16,227 Stage-1 map = 100%,  reduce = 73%, Cumulative CPU 52171.74 sec
# 2015-07-07 14:23:19,399 Stage-1 map = 100%,  reduce = 74%, Cumulative CPU 52217.34 sec
# 2015-07-07 14:23:21,520 Stage-1 map = 100%,  reduce = 75%, Cumulative CPU 52290.91 sec
# 2015-07-07 14:23:23,625 Stage-1 map = 100%,  reduce = 76%, Cumulative CPU 52393.29 sec
# 2015-07-07 14:23:27,843 Stage-1 map = 100%,  reduce = 77%, Cumulative CPU 52490.53 sec
# 2015-07-07 14:23:29,965 Stage-1 map = 100%,  reduce = 78%, Cumulative CPU 52569.52 sec
# 2015-07-07 14:23:35,243 Stage-1 map = 100%,  reduce = 79%, Cumulative CPU 52702.89 sec
# 2015-07-07 14:23:39,452 Stage-1 map = 100%,  reduce = 80%, Cumulative CPU 52808.65 sec
# 2015-07-07 14:23:44,742 Stage-1 map = 100%,  reduce = 81%, Cumulative CPU 52888.08 sec
# 2015-07-07 14:23:46,842 Stage-1 map = 100%,  reduce = 82%, Cumulative CPU 52939.91 sec
# 2015-07-07 14:23:51,074 Stage-1 map = 100%,  reduce = 83%, Cumulative CPU 53006.74 sec
# 2015-07-07 14:23:55,294 Stage-1 map = 100%,  reduce = 84%, Cumulative CPU 53147.42 sec
# 2015-07-07 14:23:56,340 Stage-1 map = 100%,  reduce = 85%, Cumulative CPU 53185.47 sec
# 2015-07-07 14:23:59,516 Stage-1 map = 100%,  reduce = 86%, Cumulative CPU 53236.56 sec
# 2015-07-07 14:24:02,696 Stage-1 map = 100%,  reduce = 87%, Cumulative CPU 53329.67 sec
# 2015-07-07 14:24:04,815 Stage-1 map = 100%,  reduce = 88%, Cumulative CPU 53403.17 sec
# 2015-07-07 14:24:11,161 Stage-1 map = 100%,  reduce = 89%, Cumulative CPU 53555.96 sec
# 2015-07-07 14:24:14,336 Stage-1 map = 100%,  reduce = 90%, Cumulative CPU 53649.14 sec
# 2015-07-07 14:24:18,547 Stage-1 map = 100%,  reduce = 91%, Cumulative CPU 53711.55 sec
# 2015-07-07 14:24:22,792 Stage-1 map = 100%,  reduce = 92%, Cumulative CPU 53788.87 sec
# 2015-07-07 14:24:27,032 Stage-1 map = 100%,  reduce = 93%, Cumulative CPU 53883.48 sec
# 2015-07-07 14:24:30,207 Stage-1 map = 100%,  reduce = 94%, Cumulative CPU 53985.39 sec
# 2015-07-07 14:24:32,320 Stage-1 map = 100%,  reduce = 95%, Cumulative CPU 54025.26 sec
# 2015-07-07 14:24:36,568 Stage-1 map = 100%,  reduce = 96%, Cumulative CPU 54077.52 sec
# 2015-07-07 14:24:38,684 Stage-1 map = 100%,  reduce = 97%, Cumulative CPU 54115.57 sec
# 2015-07-07 14:24:41,850 Stage-1 map = 100%,  reduce = 98%, Cumulative CPU 54145.9 sec
# 2015-07-07 14:24:43,978 Stage-1 map = 100%,  reduce = 99%, Cumulative CPU 54188.51 sec
# 2015-07-07 14:24:45,004 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 54226.85 sec
# MapReduce Total cumulative CPU time: 0 days 15 hours 3 minutes 46 seconds 850 msec
# Ended Job = job_1427480807408_18843
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 5378  Reduce: 999   Cumulative CPU: 54226.85 sec   HDFS Read: 1586223302788 HDFS Write: 179036521 SUCCESS
# Total MapReduce CPU Time Spent: 0 days 15 hours 3 minutes 46 seconds 850 msec
# OK
# Time taken: 2714.258 seconds, Fetched: 4069283 row(s)
